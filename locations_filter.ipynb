# %%
import pandas as pd
import re

# Import csv file
file_path = 'russia_losses.csv'

# Read the dataset into a pandas DataFrame
losses_df = pd.read_csv(file_path)

# Drop the 'lost_by' and 'unit' columns from the DataFrame
losses_df = losses_df.drop(columns=['lost_by', 'unit'])

# Display the first few rows of the dataset
losses_df.head()
# Out:
#    id   type   model     status        date                 nearest_location  \
# 0   1  Tanks  T-64BV  Destroyed  2022-03-14  Rubizhne, Sievierodonetsk raion
# 1   2  Tanks  T-64BV  Destroyed  2022-03-16         Mariupol, Mariupol raion
# 2   3  Tanks  T-64BV  Destroyed  2022-03-16         Mariupol, Mariupol raion
# 3   5  Tanks  T-64BV  Destroyed  2022-03-17         Mariupol, Mariupol raion
# 4   6  Tanks  T-64BV  Destroyed  2022-03-31  Rubizhne, Sievierodonetsk raion
#
#                                      geo                             tags
# 0                    49.027241,38.343374                              NaN
# 1   47.099125851628806,37.52371337039075  Turretless, Z, Mine plow/roller
# 2    47.09869256359657,37.52353235165147                        Shattered
# 3  47.098139835697424,37.640174323260645                    Turretless, Z
# 4                      49.01122,38.39844                                Z

# %%
# Add new empty columns to the DataFrame
losses_df['town'] = None
losses_df['raion'] = None
losses_df['oblast'] = None
losses_df['front'] = None

# Extract text inside parentheses and create a new column 'extra'
losses_df['extra'] = losses_df['nearest_location'].map(
    lambda x: re.findall(r'\((.*?)\)', str(x))[0] if pd.notna(x) and re.search(r'\(.*?\)', str(x)) else None)

# Remove the extracted value from the "nearest_location" column
losses_df['nearest_location'] = losses_df['nearest_location'].apply(lambda x: re.sub(r'\(.*?\)', '', str(x)) if pd.notna(x) else x)
# losses_df.head()

# %%
# Split the 'nearest_location' column into parts, location[0] and location[1]
location = losses_df['nearest_location'].str.split(',', expand=True)

    # Process location[0] 
losses_df['raion'] = location[0].apply(
    lambda x: x if pd.notna(x) and ' raion' in str(x).lower() else None).str.lstrip()
losses_df['oblast'] = location[0].apply(
    lambda x: x if pd.notna(x) and (' oblast' in str(x).lower() or ' krai' in str(x).lower() or ' crimea ' in str(x).lower() or ' sea' in str(x).lower()) else None).str.lstrip()
losses_df['front'] = location[0].apply(
    lambda x: x if pd.notna(x) and ('ukraine' in str(x).lower() or 'russia' in str(x).lower()) else None).str.lstrip()
losses_df['town'] = location[0].apply(
    lambda x: x if pd.notna(x) and ' raion' not in str(x).lower() and ' oblast' not in str(x).lower() and ' krai' not in str(x).lower() and 'ukraine' not in str(x).lower() and 'russia' not in str(x).lower() else None).str.lstrip()

    # Process location[1] 
losses_df['raion'] = losses_df['raion'].combine_first(location[1].apply(
    lambda x: x if pd.notna(x) and ' raion' in str(x).lower() else None)).str.lstrip()
losses_df['oblast'] = losses_df['oblast'].combine_first(location[1].apply(
    lambda x: x if pd.notna(x) and (' oblast' in str(x).lower() or ' krai' in str(x).lower() or ' crimea' in str(x).lower() or ' sea' in str(x).lower()) else None)).str.lstrip()
losses_df['front'] = losses_df['front'].combine_first(location[1].apply(
    lambda x: x if pd.notna(x) and ('east ukraine' in str(x).lower() or 'russia' in str(x).lower()) else None)).str.lstrip()

    # Process column 'extra'  
losses_df['oblast'] = losses_df['oblast'].combine_first(losses_df['extra'].apply(
    lambda x: x if pd.notna(x) and (' oblast' in str(x).lower() or ' krai' in str(x).lower()) else None)).str.lstrip()

# Split 'geo' column values "{latitude, longitude}"
losses_df[['lat', 'lon']] = losses_df['geo'].str.split(',', expand=True)

# Convert the extracted columns to numeric values (if necessary)
losses_df['lat'] = pd.to_numeric(losses_df['lat'], errors='coerce')
losses_df['lon'] = pd.to_numeric(losses_df['lon'], errors='coerce')

# Drop 'nearest_location', 'extra', and 'geo' columns and rearange columns in new order
losses_df = losses_df.reindex(columns=['id', 'type', 'model', 'status', 'date', 'front', 'oblast', 'raion', 'town', 'lat', 'lon', 'tags'])

# %%
# debuging code to display selected rows 
losses_df.iloc[14150:14155]
# Out:
#           id                        type            model     status  \
# 14150  25886  Infantry fighting vehicles            MT-LB  Destroyed
# 14151  25887  Infantry fighting vehicles            MT-LB  Destroyed
# 14152  25888                       Tanks            T-62M  Abandoned
# 14153  25889                       Tanks  T-72B Obr. 2022  Abandoned
# 14154  25890  Infantry fighting vehicles         BMP-2(K)   Captured
#
#              date front oblast             raion           town        lat  \
# 14150  2024-04-18  None   None  Volnovakha raion  Volodymyrivka  47.779417
# 14151  2024-04-18  None   None  Volnovakha raion  Volodymyrivka  47.779611
# 14152  2024-04-18  None   None  Volnovakha raion  Volodymyrivka  47.779177
# 14153  2024-03-26  None   None  Kramatorsk raion          Terny  49.091949
# 14154  2022-07-23  None   None    Beryslav raion       Ivanivka  47.475077
#
#              lon                                               tags
# 14150  37.417667                          Cope cage, Expanded cabin
# 14151  37.418556                                     Expanded cabin
# 14152  37.417521  V, Mine plow/roller, Cope cage, Damaged, ☐, Ad...
# 14153  38.029221                        Z, O, V, Cope cage, Damaged
# 14154  33.386141                                                  Z

# %%
# debuging code to display selected rows 
losses_df.iloc[3636:3650]
# Out:
#         id                        type                          model  \
# 3636  6914  Infantry fighting vehicles                       BMP-2(K)
# 3637  6915  Infantry fighting vehicles                         BTR-70
# 3638  6916  Infantry fighting vehicles                         BTR-80
# 3639  6919                      Drones     Forpost reconnaissance UAV
# 3640  6920                      Drones  'Orlan-30' reconnaissance UAV
# 3641  6939  Infantry fighting vehicles                       BMP-2(K)
# 3642  6940    Self-propelled artillery           122mm 2S1 'Gvozdika'
# 3643  6949  Infantry fighting vehicles                       BMP-2(K)
# 3644  6953  Infantry fighting vehicles                          BMP-3
# 3645  6954                       Tanks                          T-72A
# 3646  6955                       Tanks                         T-80BV
# 3647  6956  Infantry fighting vehicles                     BTR-82A(M)
# 3648  6957                       Tanks                         T-80BV
# 3649  6960  Infantry fighting vehicles                    Unknown IFV
#
#          status        date         front     oblast                  raion  \
# 3636  Destroyed  2022-08-06          None       None       Kramatorsk raion
# 3637  Destroyed  2022-03-29          None       None         Mariupol raion
# 3638  Destroyed  2022-08-06          None       None            Izium raion
# 3639  Destroyed  2022-07-30          None  Black Sea                   None
# 3640   Captured  2022-08-05  East Ukraine       None                   None
# 3641  Destroyed  2022-04-21          None       None           Nizhyn raion
# 3642  Destroyed  2022-03-19          None       None            Bucha raion
# 3643  Destroyed  2022-03-31          None       None         Okhtyrka raion
# 3644  Destroyed  2022-04-18          None       None         Mariupol raion
# 3645  Destroyed  2022-04-11          None       None  Sievierodonetsk raion
# 3646  Destroyed  2022-08-07          None       None            Izium raion
# 3647  Destroyed  2022-08-07          None       None            Izium raion
# 3648  Destroyed  2022-08-06          None       None            Izium raion
# 3649  Destroyed  2022-08-07  East Ukraine       None                   None
#
#              town        lat        lon                   tags
# 3636    Mazanivka  48.994053  37.346485                    NaN
# 3637     Mariupol  47.101620  37.650460                    NaN
# 3638   Dmytrivka   49.051442  37.114945             Underwater
# 3639    Black Sea        NaN        NaN                    NaN
# 3640         None        NaN        NaN                    NaN
# 3641     Makiivka  50.666050  31.827920                    NaN
# 3642  Berestianka  50.696970  29.998580  Turretless, Shattered
# 3643       Vovkiv  50.557402  34.967619                   PL-1
# 3644     Mariupol  47.102240  37.635650             Turretless
# 3645     Borivske  48.867637  38.610248                    NaN
# 3646   Brazhkivka  49.049030  37.181860             Turretless
# 3647   Brazhkivka  49.049030  37.181860                    NaN
# 3648    Sulyhivka  49.027327  37.219409  Turretless, Shattered
# 3649         None        NaN        NaN                    NaN

# %% [markdown]
# Load REGIONS and UNIQUE_LOCATIOS data to generate regions_dict and locations_dict

# %%
# Import regions and location data
regions_path = 'regions.csv'
unique_locations_path = 'unique_locations.csv'

regions = pd.read_csv(regions_path)
unique_locations = pd.read_csv(unique_locations_path)

# Create dictionaries
regions_dict = {
    front: group.set_index('oblast')['raion'].groupby(level=0).apply(list).to_dict()
    for front, group in regions.groupby('front')
}

locations_dict = unique_locations.set_index('raion')['unique'].to_dict()

# %%
# Debugging helper: Track unmatched raions and towns
missing_raions = []
missing_towns = []

# Loop through the "losses_df" DataFrame to populate missing oblasts and fronts
for index, row in losses_df.iterrows():
    front = row['front']
    oblast = row['oblast']
    raion = row['raion']
    town = row['town']

    # Find unique locations and add "raion"
    if pd.isna(raion) and pd.notna(town):
        for locations_raion, unique in locations_dict.items():  # Iterate through unique_dict
            if town.strip().lower() in unique.strip().lower():
                losses_df.at[index, 'raion'] = locations_raion
                raion = locations_raion 
                break  # Exit the loop once a match is found

    # Check if the oblast is missing
    if pd.isna(oblast):
        found = False  # Flag to track if a match is found

        # Loop through the regions_dict to find matching raions and oblasts
        for region_front, oblast_dict in regions_dict.items():
            for region_oblast, raions in oblast_dict.items():
                # Match based on raion
                if pd.notna(raion) and raion.strip().lower() in [r.strip().lower() for r in raions]:
                    # Update oblast and front in the losses_df DataFrame
                    losses_df.at[index, 'oblast'] = region_oblast
                    losses_df.at[index, 'front'] = region_front
                    found = True
                    break
            if found:
                break

        # If still unmatched, log the missing raion or town
        if not found:
            if pd.notna(raion):
                missing_raions.append(raion)
            elif pd.notna(town):
                missing_towns.append(town)

    else:
        # If oblast is present, match to determine the front
        for region_front, oblast_dict in regions_dict.items():
            if oblast.strip().lower() in [o.strip().lower() for o in oblast_dict.keys()]:
                # Update front in the losses_df DataFrame
                losses_df.at[index, 'front'] = region_front
                break

# Debug: Output unmatched raions and towns
if missing_raions:
    print("Unmatched raions:", set(missing_raions))
if missing_towns:
    print("Unmatched towns:", set(missing_towns))

# Output the updated DataFrame
print(losses_df.head())
# Out:
#    id   type   model     status        date         front          oblast  \
# 0   1  Tanks  T-64BV  Destroyed  2022-03-14  East Ukraine  Luhansk oblast
# 1   2  Tanks  T-64BV  Destroyed  2022-03-16  East Ukraine  Donetsk oblast
# 2   3  Tanks  T-64BV  Destroyed  2022-03-16  East Ukraine  Donetsk oblast
# 3   5  Tanks  T-64BV  Destroyed  2022-03-17  East Ukraine  Donetsk oblast
# 4   6  Tanks  T-64BV  Destroyed  2022-03-31  East Ukraine  Luhansk oblast
#
#                    raion      town        lat        lon  \
# 0  Sievierodonetsk raion  Rubizhne  49.027241  38.343374
# 1         Mariupol raion  Mariupol  47.099126  37.523713
# 2         Mariupol raion  Mariupol  47.098693  37.523532
# 3         Mariupol raion  Mariupol  47.098140  37.640174
# 4  Sievierodonetsk raion  Rubizhne  49.011220  38.398440
#
#                               tags
# 0                              NaN
# 1  Turretless, Z, Mine plow/roller
# 2                        Shattered
# 3                    Turretless, Z
# 4                                Z

# %%
losses_df.iloc[8870:8888]
# Out:
#          id                        type               model     status  \
# 8870  16611                       Tanks    T-72B3 Obr. 2016  Destroyed
# 8871  16612                       Tanks        Unknown tank  Destroyed
# 8872  16613                   Transport             UAZ-452    Damaged
# 8873  16616                   Transport              GAZ-66  Destroyed
# 8874  16617                       Tanks              T-72 *  Destroyed
# 8875  16618  Infantry fighting vehicles            BMP-1(P)  Destroyed
# 8876  16619  Infantry fighting vehicles            BMP-1(P)  Destroyed
# 8877  16621                   Transport           KamAZ 6x6  Destroyed
# 8878  16622                   Transport           KamAZ 6x6  Destroyed
# 8879  16623                   Transport           KamAZ 6x6  Destroyed
# 8880  16624                   Transport           KamAZ 6x6   Captured
# 8881  16626                   Transport           KamAZ 6x6  Abandoned
# 8882  16627  Infantry fighting vehicles               MT-LB  Destroyed
# 8883  16629  Infantry fighting vehicles            BMP-2(K)  Abandoned
# 8884  16631  Infantry fighting vehicles            BMP-1(P)  Abandoned
# 8885  16632                 Engineering  TMM-3 bridge layer  Destroyed
# 8886  16633                   Transport           Ural-4320  Destroyed
# 8887  16637                   Transport           KamAZ 6x6  Destroyed
#
#             date          front           oblast                  raion  \
# 8870  2023-02-13  South Ukraine           Crimea                   None
# 8871  2023-05-29   East Ukraine   Donetsk oblast         Pokrovsk raion
# 8872  2023-05-29  South Ukraine             None                   None
# 8873  2023-05-20   East Ukraine   Luhansk oblast                   None
# 8874  2023-05-21   East Ukraine   Donetsk oblast         Pokrovsk raion
# 8875  2023-05-21   East Ukraine   Donetsk oblast         Pokrovsk raion
# 8876  2023-07-04   East Ukraine   Donetsk oblast          Bakhmut raion
# 8877  2023-03-27   East Ukraine   Luhansk oblast                   None
# 8878  2023-03-27   East Ukraine   Luhansk oblast                   None
# 8879  2023-05-22   East Ukraine   Luhansk oblast                   None
# 8880  2022-11-30   East Ukraine   Donetsk oblast       Kramatorsk raion
# 8881  2023-05-23   East Ukraine   Donetsk oblast          Bakhmut raion
# 8882  2023-05-23   East Ukraine   Donetsk oblast          Bakhmut raion
# 8883  2023-05-23   East Ukraine   Donetsk oblast          Bakhmut raion
# 8884  2023-05-24   East Ukraine   Donetsk oblast         Pokrovsk raion
# 8885  2022-06-08   East Ukraine   Donetsk oblast       Kramatorsk raion
# 8886  2023-05-24  South Ukraine  Mykolaiv oblast         Mykolaiv raion
# 8887  2023-05-24   East Ukraine   Luhansk oblast  Sievierodonetsk raion
#
#                  town        lat        lon                         tags
# 8870           Crimea        NaN        NaN  Mine plow/roller, Cope cage
# 8871     Pervomaiske         NaN        NaN                          NaN
# 8872             None        NaN        NaN                            ∇
# 8873             None        NaN        NaN                          NaN
# 8874     Pervomaiske   48.054460  37.634177                   Turretless
# 8875     Pervomaiske   48.054428  37.634295                          NaN
# 8876      Bilohorivka  48.756389  38.196357                   Turretless
# 8877             None        NaN        NaN                          NaN
# 8878             None        NaN        NaN                          NaN
# 8879             None        NaN        NaN                    Shattered
# 8880            Lyman        NaN        NaN                            Z
# 8881     Klishchiivka        NaN        NaN                      Damaged
# 8882     Klishchiivka        NaN        NaN                          NaN
# 8883     Klishchiivka        NaN        NaN                          NaN
# 8884         Avdiivka        NaN        NaN                      Damaged
# 8885          Torske   48.972972  37.981944                         O, ⧸
# 8886       Vasylivka   46.512327  31.826041                            V
# 8887  Chervonopopivka  49.141950  38.167750                          NaN

# %%
# Filter rows where 'oblast' column is None (or NaN)
empty_rows = losses_df[losses_df['front'].isna()]

# Output the filtered rows
empty_rows.to_csv('townsuknown.csv', index=False, encoding='utf-8')
print(empty_rows)
# Out:
#           id                        type  \
# 127      186                       Tanks
# 143      216                       Tanks
# 153      231                       Tanks
# 193      287                       Tanks
# 223      340                       Tanks
# ...      ...                         ...
# 18359  32701  Infantry fighting vehicles
# 18368  32712                      Drones
# 18372  32718                      Drones
# 18373  32719                      Drones
# 18374  32721                   Transport
#
#                                         model     status        date front  \
# 127                                     T-72B   Captured  2022-04-19  None
# 143                           T-72B Obr. 1989  Destroyed  2022-04-07  None
# 153                           T-72B Obr. 1989   Captured  2022-04-12  None
# 193                                    T-72B3  Destroyed  2022-04-11  None
# 223                                    T-72B3   Captured  2022-03-16  None
# ...                                       ...        ...         ...   ...
# 18359                                BMP-1(P)  Destroyed  2024-12-18  None
# 18368  ZALA Z-16 (421-16Е) reconnaissance UAV  Destroyed  2024-12-20  None
# 18372       'Orlan-10' electronic warfare UAV   Captured  2024-10-28  None
# 18373  ZALA Z-16 (421-16Е) reconnaissance UAV  Destroyed  2024-10-25  None
# 18374           KamAZ 8x8 with armoured cabin  Destroyed  2024-12-19  None
#
#       oblast raion  town  lat  lon                          tags
# 127     None  None  None  NaN  NaN                             Z
# 143     None  None  None  NaN  NaN                           NaN
# 153     None  None  None  NaN  NaN                             Z
# 193     None  None  None  NaN  NaN                    Turretless
# 223     None  None  None  NaN  NaN                             Z
# ...      ...   ...   ...  ...  ...                           ...
# 18359   None  None  None  NaN  NaN  Cope cage, Additional armour
# 18368   None  None  None  NaN  NaN                           NaN
# 18372   None  None  None  NaN  NaN                           NaN
# 18373   None  None  None  NaN  NaN                           NaN
# 18374   None  None  None  NaN  NaN                             Z
#
# [1071 rows x 12 columns]

# %%
losses_df.iloc[16800:16815]
# Out:
#           id                        type  \
# 16800  30134                   Transport
# 16801  30135  Infantry fighting vehicles
# 16802  30136  Infantry fighting vehicles
# 16803  30138                       Tanks
# 16804  30139                      Drones
# 16805  30140                 Helicopters
# 16806  30144  Infantry fighting vehicles
# 16807  30145             Towed artillery
# 16808  30146                   Transport
# 16809  30148  Infantry fighting vehicles
# 16810  30158                       Tanks
# 16811  30159  Infantry fighting vehicles
# 16812  30163  Infantry fighting vehicles
# 16813  30164  Infantry fighting vehicles
# 16814  30165  Infantry fighting vehicles
#
#                                         model     status        date  \
# 16800                                 ZiL-131  Destroyed  2024-09-19
# 16801                              BTR-82A(M)  Destroyed  2024-09-24
# 16802                                   MT-LB  Destroyed  2024-09-24
# 16803                                   T-80U  Destroyed  2024-09-24
# 16804  ZALA Z-16 (421-16Е) reconnaissance UAV   Captured  2024-09-04
# 16805          Mi-8AMTSh transport helicopter  Destroyed  2024-09-23
# 16806                      BMP-3 688A-sb6-2KP  Destroyed  2024-09-23
# 16807                122mm 2A18 D-30 howitzer  Destroyed  2024-09-23
# 16808                              MAZ-531605  Destroyed  2024-09-23
# 16809                                   MT-LB  Destroyed  2024-09-21
# 16810          Unknown T-72 Obr. 2022 variant  Destroyed  2024-09-18
# 16811                                BMP-2(K)  Destroyed  2024-09-23
# 16812                                   MT-LB  Destroyed  2024-07-22
# 16813                      BMP-1AM 675-sb3KDZ  Destroyed  2024-09-25
# 16814                      BMP-1AM 675-sb3KDZ  Destroyed  2024-09-25
#
#                 front          oblast                  raion  \
# 16800    East Ukraine  Luhansk oblast  Sievierodonetsk raion
# 16801  Central Russia    Kursk oblast           Sudzha raion
# 16802    East Ukraine  Luhansk oblast          Svatove raion
# 16803            None            None                   None
# 16804            None            None                   None
# 16805  Siberia Russia     Omsk oblast                   None
# 16806  Central Russia    Kursk oblast           Sudzha raion
# 16807    East Ukraine  Luhansk oblast  Sievierodonetsk raion
# 16808    East Ukraine  Luhansk oblast          Svatove raion
# 16809  Central Russia    Kursk oblast           Sudzha raion
# 16810    East Ukraine  Donetsk oblast         Pokrovsk raion
# 16811    East Ukraine  Donetsk oblast                   None
# 16812    East Ukraine  Donetsk oblast          Bakhmut raion
# 16813    East Ukraine  Donetsk oblast         Pokrovsk raion
# 16814    East Ukraine  Donetsk oblast         Pokrovsk raion
#
#                    town        lat        lon  \
# 16800              None        NaN        NaN
# 16801          Dyakovka  51.406583  35.271833
# 16802         Kovalivka        NaN        NaN
# 16803              None        NaN        NaN
# 16804              None        NaN        NaN
# 16805              Omsk        NaN        NaN
# 16806  Nikolaevo-Darino  51.238510  34.951390
# 16807          Kreminna        NaN        NaN
# 16808           Svatove  49.443282  38.175367
# 16809          Plekhovo        NaN        NaN
# 16810    Kostiantynivka        NaN        NaN
# 16811              None        NaN        NaN
# 16812            Spirne  48.800614  38.242243
# 16813         Tsukuryne  48.098305  37.313275
# 16814          Ukrainsk  48.098672  37.338428
#
#                                        tags
# 16800                                  KUNG
# 16801                                   NaN
# 16802  Cope cage, Jammer, Additional armour
# 16803                            Turretless
# 16804                                   NaN
# 16805                                   NaN
# 16806                 Turretless, Cope cage
# 16807                                   NaN
# 16808                                   NaN
# 16809             Cope cage, Expanded cabin
# 16810           Mine plow/roller, Cope cage
# 16811                             Cope cage
# 16812                             Cope cage
# 16813                             Cope cage
# 16814                             Cope cage

# %%
losses_df.to_csv('russia_losses_clean_locations.csv', index=False, encoding='utf-8')
