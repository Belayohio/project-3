# %%
import re
import requests
import pandas as pd
from bs4 import BeautifulSoup
import json
from pprint import pprint

# Base URL of the API
url = 'https://ukr.warspotting.net/api/losses/russia/'
headers = {'User-Agent': 'Chrome'}

# Base URL of the API
url = 'https://ukr.warspotting.net/api/losses/russia/'
headers = {'User-Agent': 'Chrome'}

# Create a csv file to store data
df.to_csv("russia_losses.csv", index=False)

# Initialize a list to store all data
data = []
id = 1
previous_id = None  # To track the last fetched ID

try:
    while True:
        # Fetch data for the current ID
        response = requests.get(f"{url}{id}", headers=headers)
        response.raise_for_status()  # Raise an HTTPError for bad responses
        response_json = response.json()  # Parse JSON response     

        # Append the losses to the data list
        data.extend(response_json['losses'])

        # Extract the last ID from the losses
        last_id = response_json['losses'][-1]['id']

        # Check if the last ID is the same as the previous ID (to avoid infinite loop)
        if last_id == previous_id:
            print("No new data found. Stopping.")
            break

        # Update the previous ID and the new ID for the next request
        previous_id = last_id
        id = last_id + 1

        # Debug print to see progress
        print(f"Fetched up to ID {last_id}")

        # Convert the current batch to a DataFrame and append to CSV
        current_df = pd.DataFrame(response_json['losses'])
        with open("russia_losses.csv", mode='a', newline='', encoding='utf-8') as f:
            current_df.to_csv(f, header=f.tell() == 0, index=False)

except requests.exceptions.RequestException as e:
    print(f"Error fetching data: {e}")
except KeyError as e:
    print(f"KeyError: {e}")
except ValueError as e:
    print(f"ValueError: {e}")

# Combine and print final data
if data:
    df = pd.DataFrame(data)
    print("Final DataFrame:")
    print(df)
else:
    print("No data was fetched.")
# Out:
# Fetched up to ID 148
# Fetched up to ID 298
# Fetched up to ID 457
# Fetched up to ID 588
# Fetched up to ID 788
# Fetched up to ID 946
# Fetched up to ID 1080
# Fetched up to ID 1301
# Fetched up to ID 1450
# Fetched up to ID 1612
# Fetched up to ID 1764
# Fetched up to ID 1919
# Fetched up to ID 2049
# Fetched up to ID 2192
# Fetched up to ID 2335
# Fetched up to ID 2456
# Fetched up to ID 2611
# Fetched up to ID 2745
# Fetched up to ID 2882
# Fetched up to ID 3009
# Fetched up to ID 3135
# Fetched up to ID 3246
# Fetched up to ID 3390
# Fetched up to ID 3521
# Fetched up to ID 3638
# Fetched up to ID 3775
# Fetched up to ID 3916
# Fetched up to ID 4073
# Fetched up to ID 4262
# Fetched up to ID 5662
# Fetched up to ID 5846
# Fetched up to ID 6063
# Fetched up to ID 6239
# Fetched up to ID 6486
# Fetched up to ID 6600
# Fetched up to ID 6782
# Fetched up to ID 7076
# Fetched up to ID 7276
# Fetched up to ID 7438
# Fetched up to ID 7590
# Fetched up to ID 7816
# Fetched up to ID 7990
# Fetched up to ID 8154
# Fetched up to ID 8275
# Fetched up to ID 8415
# Fetched up to ID 8561
# Fetched up to ID 8693
# Fetched up to ID 8843
# Fetched up to ID 8989
# Fetched up to ID 9160
# Fetched up to ID 9329
# Fetched up to ID 9518
# Fetched up to ID 9687
# Fetched up to ID 9840
# Fetched up to ID 10021
# Fetched up to ID 10212
# Fetched up to ID 10374
# Fetched up to ID 10583
# Fetched up to ID 10784
# Fetched up to ID 10985
# Fetched up to ID 11158
# Fetched up to ID 11380
# Fetched up to ID 11543
# Fetched up to ID 11744
# Fetched up to ID 11942
# Fetched up to ID 12147
# Fetched up to ID 12327
# Fetched up to ID 12453
# Fetched up to ID 12638
# Fetched up to ID 12834
# Fetched up to ID 13047
# Fetched up to ID 13264
# Fetched up to ID 13495
# Fetched up to ID 13707
# Fetched up to ID 13880
# Fetched up to ID 14053
# Fetched up to ID 14228
# Fetched up to ID 14409
# Fetched up to ID 14590
# Fetched up to ID 14777
# Fetched up to ID 14956
# Fetched up to ID 15156
# Fetched up to ID 15379
# Fetched up to ID 15596
# Fetched up to ID 15847
# Fetched up to ID 16051
# Fetched up to ID 16299
# Fetched up to ID 16490
# Fetched up to ID 16662
# Fetched up to ID 16953
# Fetched up to ID 17197
# Fetched up to ID 17395
# Fetched up to ID 17600
# Fetched up to ID 17798
# Fetched up to ID 17999
# Fetched up to ID 18179
# Fetched up to ID 18402
# Fetched up to ID 18605
# Fetched up to ID 18851
# Fetched up to ID 19054
# Fetched up to ID 19238
# Fetched up to ID 19435
# Fetched up to ID 19607
# Fetched up to ID 19763
# Fetched up to ID 19947
# Fetched up to ID 20149
# Fetched up to ID 20342
# Fetched up to ID 20523
# Fetched up to ID 20684
# Fetched up to ID 20818
# Fetched up to ID 20992
# Fetched up to ID 21175
# Fetched up to ID 21332
# Fetched up to ID 21496
# Fetched up to ID 21647
# Fetched up to ID 21808
# Fetched up to ID 21973
# Fetched up to ID 22148
# Fetched up to ID 22312
# Fetched up to ID 22470
# Fetched up to ID 22623
# Fetched up to ID 22794
# Fetched up to ID 22944
# Fetched up to ID 23141
# Fetched up to ID 23318
# Fetched up to ID 23466
# Fetched up to ID 23603
# Fetched up to ID 23755
# Fetched up to ID 23917
# Fetched up to ID 24096
# Fetched up to ID 24253
# Fetched up to ID 24430
# Fetched up to ID 24611
# Fetched up to ID 24756
# Fetched up to ID 24908
# Fetched up to ID 25050
# Fetched up to ID 25213
# Fetched up to ID 25369
# Fetched up to ID 25518
# Fetched up to ID 25661
# Fetched up to ID 25805
# Fetched up to ID 25958
# Fetched up to ID 26121
# Fetched up to ID 26282
# Fetched up to ID 26460
# Fetched up to ID 26632
# Fetched up to ID 26793
# Fetched up to ID 26941
# Fetched up to ID 27082
# Fetched up to ID 27237
# Fetched up to ID 27376
# Fetched up to ID 27536
# Fetched up to ID 27676
# Fetched up to ID 27820
# Fetched up to ID 27979
# Fetched up to ID 28130
# Fetched up to ID 28280
# Fetched up to ID 28449
# Fetched up to ID 28606
# Fetched up to ID 28754
# Fetched up to ID 28932
# Fetched up to ID 29106
# Fetched up to ID 29293
# Fetched up to ID 29475
# Fetched up to ID 29645
# Fetched up to ID 29821
# Fetched up to ID 29975
# Fetched up to ID 30131
# Fetched up to ID 30287
# Fetched up to ID 30452
# Fetched up to ID 30618
# Fetched up to ID 30777
# Fetched up to ID 30929
# Fetched up to ID 31087
# Fetched up to ID 31253
# Fetched up to ID 31417
# Fetched up to ID 31609
# Fetched up to ID 31754
# Fetched up to ID 31915
# Fetched up to ID 32077
# Fetched up to ID 32260
# Fetched up to ID 32403
# Fetched up to ID 32584
# Fetched up to ID 32688
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 33
#      30 data.extend(response_json['losses'])
#      32 # Extract the last ID from the losses
# ---> 33 last_id = response_json['losses'][-1]['id']
#      35 # Check if the last ID is the same as the previous ID (to avoid infinite loop)
#      36 if last_id == previous_id:
#
# IndexError: list index out of range
