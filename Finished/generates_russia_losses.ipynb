# %%
import requests
import pandas as pd
from pprint import pprint

# Base URL of the API
url = 'https://ukr.warspotting.net/api/losses/russia/'
headers = {'User-Agent': 'Chrome'}

# Initialize a list to store all data
data = []
id = 1
previous_id = None  # To track the last fetched ID

try:
    while True:
        # Fetch data for the current ID
        response = requests.get(f"{url}{id}", headers=headers)
        response.raise_for_status()  # Raise an HTTPError for bad responses
        response_json = response.json()  # Parse JSON response     

        # Check if the data exists and is not empty
        if 'losses' not in response_json or not response_json['losses']:
            print("No more data found. Stopping.")
            break

        # Append the losses to the data list
        data.extend(response_json['losses'])

        # Extract the last ID from the losses
        last_id = response_json['losses'][-1]['id']

        # Check if the last ID is the same as the previous ID (to avoid infinite loop)
        if last_id == previous_id:
            print("No new data found. Stopping.")
            break

        # Update the previous ID and the new ID for the next request
        previous_id = last_id
        id = last_id + 1

        # Debug print to see progress
        print(f"Fetched up to ID {last_id}")

        # Convert the current batch to a DataFrame and append to CSV
        current_df = pd.DataFrame(response_json['losses'])
        with open("russia_losses.csv", mode='a', newline='', encoding='utf-8') as f:
            current_df.to_csv(f, header=f.tell() == 0, index=False)

except requests.exceptions.RequestException as e:
    print(f"Error fetching data: {e}")
except KeyError as e:
    print(f"KeyError: {e}")
except ValueError as e:
    print(f"ValueError: {e}")

# Combine and print final data
if data:
    df = pd.DataFrame(data)
    print("Final DataFrame:")
    print(df)
else:
    print("No data was fetched.")
# Out:
# Fetched up to ID 148
# Fetched up to ID 298
# Fetched up to ID 459
# Fetched up to ID 589
# Fetched up to ID 793
# Fetched up to ID 947
# Fetched up to ID 1081
# Fetched up to ID 1302
# Fetched up to ID 1451
# Fetched up to ID 1613
# Fetched up to ID 1765
# Fetched up to ID 1920
# Fetched up to ID 2052
# Fetched up to ID 2193
# Fetched up to ID 2339
# Fetched up to ID 2457
# Fetched up to ID 2616
# Fetched up to ID 2748
# Fetched up to ID 2885
# Fetched up to ID 3012
# Fetched up to ID 3138
# Fetched up to ID 3253
# Fetched up to ID 3395
# Fetched up to ID 3526
# Fetched up to ID 3642
# Fetched up to ID 3780
# Fetched up to ID 3920
# Fetched up to ID 4078
# Fetched up to ID 4267
# Fetched up to ID 5666
# Fetched up to ID 5851
# Fetched up to ID 6070
# Fetched up to ID 6243
# Fetched up to ID 6490
# Fetched up to ID 6604
# Fetched up to ID 6787
# Fetched up to ID 7079
# Fetched up to ID 7279
# Fetched up to ID 7441
# Fetched up to ID 7593
# Fetched up to ID 7823
# Fetched up to ID 7993
# Fetched up to ID 8157
# Fetched up to ID 8278
# Fetched up to ID 8418
# Fetched up to ID 8564
# Fetched up to ID 8696
# Fetched up to ID 8849
# Fetched up to ID 8993
# Fetched up to ID 9164
# Fetched up to ID 9332
# Fetched up to ID 9521
# Fetched up to ID 9694
# Fetched up to ID 9843
# Fetched up to ID 10025
# Fetched up to ID 10215
# Fetched up to ID 10377
# Fetched up to ID 10587
# Fetched up to ID 10790
# Fetched up to ID 10988
# Fetched up to ID 11181
# Fetched up to ID 11384
# Fetched up to ID 11551
# Fetched up to ID 11747
# Fetched up to ID 11945
# Fetched up to ID 12153
# Fetched up to ID 12333
# Fetched up to ID 12458
# Fetched up to ID 12642
# Fetched up to ID 12839
# Fetched up to ID 13053
# Fetched up to ID 13287
# Fetched up to ID 13503
# Fetched up to ID 13718
# Fetched up to ID 13894
# Fetched up to ID 14101
# Fetched up to ID 14293
# Fetched up to ID 14465
# Fetched up to ID 14660
# Fetched up to ID 14849
# Fetched up to ID 15040
# Fetched up to ID 15232
# Fetched up to ID 15492
# Fetched up to ID 15706
# Fetched up to ID 15954
# Fetched up to ID 16182
# Fetched up to ID 16402
# Fetched up to ID 16589
# Fetched up to ID 16829
# Fetched up to ID 17111
# Fetched up to ID 17336
# Fetched up to ID 17531
# Fetched up to ID 17723
# Fetched up to ID 17951
# Fetched up to ID 18151
# Fetched up to ID 18345
# Fetched up to ID 18576
# Fetched up to ID 18807
# Fetched up to ID 19023
# Fetched up to ID 19216
# Fetched up to ID 19420
# Fetched up to ID 19587
# Fetched up to ID 19749
# Fetched up to ID 19941
# Fetched up to ID 20142
# Fetched up to ID 20328
# Fetched up to ID 20539
# Fetched up to ID 20694
# Fetched up to ID 20843
# Fetched up to ID 21039
# Fetched up to ID 21233
# Fetched up to ID 21387
# Fetched up to ID 21566
# Fetched up to ID 21726
# Fetched up to ID 21896
# Fetched up to ID 22090
# Fetched up to ID 22263
# Fetched up to ID 22431
# Fetched up to ID 22607
# Fetched up to ID 22778
# Fetched up to ID 22934
# Fetched up to ID 23129
# Fetched up to ID 23305
# Fetched up to ID 23460
# Fetched up to ID 23598
# Fetched up to ID 23753
# Fetched up to ID 23916
# Fetched up to ID 24099
# Fetched up to ID 24258
# Fetched up to ID 24443
# Fetched up to ID 24617
# Fetched up to ID 24762
# Fetched up to ID 24914
# Fetched up to ID 25055
# Fetched up to ID 25224
# Fetched up to ID 25374
# Fetched up to ID 25530
# Fetched up to ID 25672
# Fetched up to ID 25815
# Fetched up to ID 25971
# Fetched up to ID 26128
# Fetched up to ID 26298
# Fetched up to ID 26473
# Fetched up to ID 26644
# Fetched up to ID 26804
# Fetched up to ID 26952
# Fetched up to ID 27097
# Fetched up to ID 27251
# Fetched up to ID 27384
# Fetched up to ID 27548
# Fetched up to ID 27686
# Fetched up to ID 27828
# Fetched up to ID 27986
# Fetched up to ID 28139
# Fetched up to ID 28294
# Fetched up to ID 28464
# Fetched up to ID 28617
# Fetched up to ID 28773
# Fetched up to ID 28957
# Fetched up to ID 29117
# Fetched up to ID 29317
# Fetched up to ID 29497
# Fetched up to ID 29663
# Fetched up to ID 29833
# Fetched up to ID 29993
# Fetched up to ID 30144
# Fetched up to ID 30298
# Fetched up to ID 30465
# Fetched up to ID 30626
# Fetched up to ID 30791
# Fetched up to ID 30947
# Fetched up to ID 31097
# Fetched up to ID 31267
# Fetched up to ID 31429
# Fetched up to ID 31628
# Fetched up to ID 31771
# Fetched up to ID 31939
# Fetched up to ID 32098
# Fetched up to ID 32279
# Fetched up to ID 32425
# Fetched up to ID 32608
# Fetched up to ID 32784
# Fetched up to ID 32959
# Fetched up to ID 33144
# No more data found. Stopping.
# Final DataFrame:
#           id                        type             model     status lost_by  \
# 0          1                       Tanks            T-64BV  Destroyed  Russia
# 1          2                       Tanks            T-64BV  Destroyed  Russia
# 2          3                       Tanks            T-64BV  Destroyed  Russia
# 3          5                       Tanks            T-64BV  Destroyed  Russia
# 4          6                       Tanks            T-64BV  Destroyed  Russia
# ...      ...                         ...               ...        ...     ...
# 18394  33133  Infantry fighting vehicles  BMP-1 675-sb3KDZ  Destroyed  Russia
# 18395  33136  Infantry fighting vehicles          BMP-1(P)  Abandoned  Russia
# 18396  33137  Infantry fighting vehicles             BTR-D  Destroyed  Russia
# 18397  33143  Infantry fighting vehicles  BMP-2 675-sb3KDZ  Destroyed  Russia
# 18398  33144                       Tanks            T-62 *  Abandoned  Russia
#
#              date                 nearest_location  \
# 0      2022-03-14  Rubizhne, Sievierodonetsk raion
# 1      2022-03-16         Mariupol, Mariupol raion
# 2      2022-03-16         Mariupol, Mariupol raion
# 3      2022-03-17         Mariupol, Mariupol raion
# 4      2022-03-31  Rubizhne, Sievierodonetsk raion
# ...           ...                              ...
# 18394  2025-01-05   Pokrovsk raion, Donetsk oblast
# 18395  2025-01-07   Pokrovsk raion, Donetsk oblast
# 18396  2025-01-07       Nizhnii Klin, Sudzha raion
# 18397  2024-11-30              Zaporizhzhia oblast
# 18398  2025-01-07     Yampolivka, Kramatorsk raion
#
#                                          geo  \
# 0                        49.027241,38.343374
# 1       47.099125851628806,37.52371337039075
# 2        47.09869256359657,37.52353235165147
# 3      47.098139835697424,37.640174323260645
# 4                          49.01122,38.39844
# ...                                      ...
# 18394                                   None
# 18395                                   None
# 18396                    51.291306,35.116389
# 18397                                   None
# 18398                    49.056444,38.040167
#
#                                     unit  \
# 0                                   None
# 1                                   None
# 2                                   None
# 3                                   None
# 4                                   None
# ...                                  ...
# 18394                               None
# 18395                               None
# 18396  234th Guards Air Assault Regiment
# 18397                               None
# 18398                               None
#
#                                            tags
# 0                                          None
# 1               Turretless, Z, Mine plow/roller
# 2                                     Shattered
# 3                                 Turretless, Z
# 4                                             Z
# ...                                         ...
# 18394                         Cope cage, Jammer
# 18395  Cope cage, Damaged, Additional armour, O
# 18396      Cope cage, Additional armour, Jammer
# 18397                  PL-1, Armour kit missing
# 18398                           Damaged, Turtle
#
# [18399 rows x 10 columns]

# %%
# Combine and save final data as a DataFrame
if data:
    df = pd.DataFrame(data)
    print("Final DataFrame:")
    print(df)
    
else:
    print("No data was fetched.")
# Out:
# Final DataFrame:
#           id                        type             model     status lost_by  \
# 0          1                       Tanks            T-64BV  Destroyed  Russia
# 1          2                       Tanks            T-64BV  Destroyed  Russia
# 2          3                       Tanks            T-64BV  Destroyed  Russia
# 3          5                       Tanks            T-64BV  Destroyed  Russia
# 4          6                       Tanks            T-64BV  Destroyed  Russia
# ...      ...                         ...               ...        ...     ...
# 18394  33133  Infantry fighting vehicles  BMP-1 675-sb3KDZ  Destroyed  Russia
# 18395  33136  Infantry fighting vehicles          BMP-1(P)  Abandoned  Russia
# 18396  33137  Infantry fighting vehicles             BTR-D  Destroyed  Russia
# 18397  33143  Infantry fighting vehicles  BMP-2 675-sb3KDZ  Destroyed  Russia
# 18398  33144                       Tanks            T-62 *  Abandoned  Russia
#
#              date                 nearest_location  \
# 0      2022-03-14  Rubizhne, Sievierodonetsk raion
# 1      2022-03-16         Mariupol, Mariupol raion
# 2      2022-03-16         Mariupol, Mariupol raion
# 3      2022-03-17         Mariupol, Mariupol raion
# 4      2022-03-31  Rubizhne, Sievierodonetsk raion
# ...           ...                              ...
# 18394  2025-01-05   Pokrovsk raion, Donetsk oblast
# 18395  2025-01-07   Pokrovsk raion, Donetsk oblast
# 18396  2025-01-07       Nizhnii Klin, Sudzha raion
# 18397  2024-11-30              Zaporizhzhia oblast
# 18398  2025-01-07     Yampolivka, Kramatorsk raion
#
#                                          geo  \
# 0                        49.027241,38.343374
# 1       47.099125851628806,37.52371337039075
# 2        47.09869256359657,37.52353235165147
# 3      47.098139835697424,37.640174323260645
# 4                          49.01122,38.39844
# ...                                      ...
# 18394                                   None
# 18395                                   None
# 18396                    51.291306,35.116389
# 18397                                   None
# 18398                    49.056444,38.040167
#
#                                     unit  \
# 0                                   None
# 1                                   None
# 2                                   None
# 3                                   None
# 4                                   None
# ...                                  ...
# 18394                               None
# 18395                               None
# 18396  234th Guards Air Assault Regiment
# 18397                               None
# 18398                               None
#
#                                            tags
# 0                                          None
# 1               Turretless, Z, Mine plow/roller
# 2                                     Shattered
# 3                                 Turretless, Z
# 4                                             Z
# ...                                         ...
# 18394                         Cope cage, Jammer
# 18395  Cope cage, Damaged, Additional armour, O
# 18396      Cope cage, Additional armour, Jammer
# 18397                  PL-1, Armour kit missing
# 18398                           Damaged, Turtle
#
# [18399 rows x 10 columns]

# %%
# Save the DataFrame to a CSV file
df.to_csv(csv_file, index=False, encoding='utf-8')
print(f"Data saved to {csv_file}")
# Out:
# Data saved to russia_losses.csv
