# %%
import requests
import pandas as pd

# Base URL of the API
url = 'https://ukr.warspotting.net/api/losses/russia/'
headers = {'User-Agent': 'Chrome'}

# CSV file to store the final data
csv_file = "russia_losses.csv"

# Initialize a list to store all data
data = []
id = 1

try:
    while True:
        # Fetch data for the current ID
        response = requests.get(f"{url}{id}", headers=headers)
        response.raise_for_status()  # Raise an HTTPError for bad responses
        response_json = response.json()  # Parse JSON response     

        # Check if response_json.get('losses') is an empty list, stop the loop
        if not response_json.get('losses'):
            print(f"No data found for ID {id}. Stopping.")
            break

        # Append the losses to the data list
        data.extend(response_json['losses'])

        # Debug print to see progress
        print(f"Fetched data for ID {id}")

        # Update the ID for the next request
        id += 1

# Standart error messages
except requests.exceptions.RequestException as e:
    print(f"Error fetching data: {e}")
except KeyError as e:
    print(f"KeyError: {e}")
except ValueError as e:
    print(f"ValueError: {e}")
# Out:
# Fetched up to ID 148
# Fetched up to ID 298
# Fetched up to ID 457
# Fetched up to ID 588
# Fetched up to ID 788
# Fetched up to ID 946
# Fetched up to ID 1080
# Fetched up to ID 1301
# Fetched up to ID 1450
# Fetched up to ID 1612
# Fetched up to ID 1764
# Fetched up to ID 1919
# Fetched up to ID 2049
# Fetched up to ID 2192
# Fetched up to ID 2335
# Fetched up to ID 2456
# Fetched up to ID 2611
# Fetched up to ID 2745
# Fetched up to ID 2882
# Fetched up to ID 3009
# Fetched up to ID 3135
# Fetched up to ID 3247
# Fetched up to ID 3391
# Fetched up to ID 3522
# Fetched up to ID 3639
# Fetched up to ID 3776
# Fetched up to ID 3917
# Fetched up to ID 4074
# Fetched up to ID 4264
# Fetched up to ID 5663
# Fetched up to ID 5848
# Fetched up to ID 6067
# Fetched up to ID 6240
# Fetched up to ID 6487
# Fetched up to ID 6601
# Fetched up to ID 6784
# Fetched up to ID 7077
# Fetched up to ID 7277
# Fetched up to ID 7439
# Fetched up to ID 7591
# Fetched up to ID 7817
# Fetched up to ID 7991
# Fetched up to ID 8155
# Fetched up to ID 8276
# Fetched up to ID 8416
# Fetched up to ID 8562
# Fetched up to ID 8694
# Fetched up to ID 8844
# Fetched up to ID 8991
# Fetched up to ID 9161
# Fetched up to ID 9330
# Fetched up to ID 9519
# Fetched up to ID 9688
# Fetched up to ID 9841
# Fetched up to ID 10022
# Fetched up to ID 10213
# Fetched up to ID 10375
# Fetched up to ID 10585
# Fetched up to ID 10788
# Fetched up to ID 10986
# Fetched up to ID 11178
# Fetched up to ID 11381
# Fetched up to ID 11544
# Fetched up to ID 11745
# Fetched up to ID 11943
# Fetched up to ID 12149
# Fetched up to ID 12328
# Fetched up to ID 12456
# Fetched up to ID 12639
# Fetched up to ID 12835
# Fetched up to ID 13048
# Fetched up to ID 13267
# Fetched up to ID 13499
# Fetched up to ID 13710
# Fetched up to ID 13881
# Fetched up to ID 14054
# Fetched up to ID 14233
# Fetched up to ID 14410
# Fetched up to ID 14591
# Fetched up to ID 14778
# Fetched up to ID 14957
# Fetched up to ID 15157
# Fetched up to ID 15382
# Fetched up to ID 15597
# Fetched up to ID 15848
# Fetched up to ID 16052
# Fetched up to ID 16300
# Fetched up to ID 16491
# Fetched up to ID 16663
# Fetched up to ID 16954
# Fetched up to ID 17198
# Fetched up to ID 17400
# Fetched up to ID 17605
# Fetched up to ID 17800
# Fetched up to ID 18000
# Fetched up to ID 18180
# Fetched up to ID 18403
# Fetched up to ID 18606
# Fetched up to ID 18852
# Fetched up to ID 19055
# Fetched up to ID 19239
# Fetched up to ID 19439
# Fetched up to ID 19609
# Fetched up to ID 19764
# Fetched up to ID 19948
# Fetched up to ID 20150
# Fetched up to ID 20343
# Fetched up to ID 20526
# Fetched up to ID 20685
# Fetched up to ID 20820
# Fetched up to ID 20995
# Fetched up to ID 21177
# Fetched up to ID 21334
# Fetched up to ID 21497
# Fetched up to ID 21648
# Fetched up to ID 21809
# Fetched up to ID 21975
# Fetched up to ID 22155
# Fetched up to ID 22313
# Fetched up to ID 22471
# Fetched up to ID 22624
# Fetched up to ID 22796
# Fetched up to ID 22945
# Fetched up to ID 23142
# Fetched up to ID 23319
# Fetched up to ID 23467
# Fetched up to ID 23604
# Fetched up to ID 23756
# Fetched up to ID 23918
# Fetched up to ID 24097
# Fetched up to ID 24254
# Fetched up to ID 24431
# Fetched up to ID 24612
# Fetched up to ID 24757
# Fetched up to ID 24909
# Fetched up to ID 25051
# Fetched up to ID 25217
# Fetched up to ID 25370
# Fetched up to ID 25521
# Fetched up to ID 25662
# Fetched up to ID 25806
# Fetched up to ID 25959
# Fetched up to ID 26122
# Fetched up to ID 26284
# Fetched up to ID 26461
# Fetched up to ID 26635
# Fetched up to ID 26794
# Fetched up to ID 26942
# Fetched up to ID 27083
# Fetched up to ID 27240
# Fetched up to ID 27377
# Fetched up to ID 27537
# Fetched up to ID 27677
# Fetched up to ID 27821
# Fetched up to ID 27980
# Fetched up to ID 28131
# Fetched up to ID 28283
# Fetched up to ID 28450
# Fetched up to ID 28608
# Fetched up to ID 28755
# Fetched up to ID 28933
# Fetched up to ID 29107
# Fetched up to ID 29295
# Fetched up to ID 29478
# Fetched up to ID 29647
# Fetched up to ID 29822
# Fetched up to ID 29976
# Fetched up to ID 30132
# Fetched up to ID 30289
# Fetched up to ID 30453
# Fetched up to ID 30619
# Fetched up to ID 30778
# Fetched up to ID 30930
# Fetched up to ID 31088
# Fetched up to ID 31254
# Fetched up to ID 31418
# Fetched up to ID 31610
# Fetched up to ID 31755
# Fetched up to ID 31917
# Fetched up to ID 32079
# Fetched up to ID 32261
# Fetched up to ID 32404
# Fetched up to ID 32584
# Fetched up to ID 32733
# No data found for ID 32734. Stopping.
# Final DataFrame:
#           id                        type               model     status  \
# 0          1                       Tanks              T-64BV  Destroyed
# 1          2                       Tanks              T-64BV  Destroyed
# 2          3                       Tanks              T-64BV  Destroyed
# 3          5                       Tanks              T-64BV  Destroyed
# 4          6                       Tanks              T-64BV  Destroyed
# ...      ...                         ...                 ...        ...
# 18377  32729  Infantry fighting vehicles               BMD-2  Abandoned
# 18378  32730  Infantry fighting vehicles  BMP-1AM 675-sb3KDZ  Destroyed
# 18379  32731  Infantry fighting vehicles               BMP-3  Destroyed
# 18380  32732  Infantry fighting vehicles            BMP-2(K)  Destroyed
# 18381  32733                       Tanks        Unknown tank  Destroyed
#
#       lost_by        date                                   nearest_location  \
# 0      Russia  2022-03-14                    Rubizhne, Sievierodonetsk raion
# 1      Russia  2022-03-16                           Mariupol, Mariupol raion
# 2      Russia  2022-03-16                           Mariupol, Mariupol raion
# 3      Russia  2022-03-17                           Mariupol, Mariupol raion
# 4      Russia  2022-03-31                    Rubizhne, Sievierodonetsk raion
# ...       ...         ...                                                ...
# 18377  Russia  2024-12-21                               Darino, Sudzha raion
# 18378  Russia  2024-12-21                         Sukhi Yaly, Pokrovsk raion
# 18379  Russia  2024-11-30       Pershotravneve (Borova hromada), Izium raion
# 18380  Russia  2024-12-19  Pishchane (Petropavlivka hromada), Kupiansk raion
# 18381  Russia  2024-12-19  Pishchane (Petropavlivka hromada), Kupiansk raion
#
#                                          geo  unit  \
# 0                        49.027241,38.343374  None
# 1       47.099125851628806,37.52371337039075  None
# 2        47.09869256359657,37.52353235165147  None
# 3      47.098139835697424,37.640174323260645  None
# 4                          49.01122,38.39844  None
# ...                                      ...   ...
# 18377                    51.267278,35.031333  None
# 18378                                   None  None
# 18379                                   None  None
# 18380                    49.572472,37.764583  None
# 18381                     49.572333,37.76475  None
#
#                                   tags
# 0                                 None
# 1      Turretless, Z, Mine plow/roller
# 2                            Shattered
# 3                        Turretless, Z
# 4                                    Z
# ...                                ...
# 18377                        Cope cage
# 18378                        Cope cage
# 18379                Cope cage, Jammer
# 18380            Turretless, Cope cage
# 18381     Cope cage, Additional armour
#
# [18382 rows x 10 columns]

# %%
# Combine and save final data as a DataFrame
if data:
    df = pd.DataFrame(data)
    print("Final DataFrame:")
    print(df)
    
else:
    print("No data was fetched.")
# Out:
# Final DataFrame:
#           id                        type               model     status  \
# 0          1                       Tanks              T-64BV  Destroyed
# 1          2                       Tanks              T-64BV  Destroyed
# 2          3                       Tanks              T-64BV  Destroyed
# 3          5                       Tanks              T-64BV  Destroyed
# 4          6                       Tanks              T-64BV  Destroyed
# ...      ...                         ...                 ...        ...
# 18377  32729  Infantry fighting vehicles               BMD-2  Abandoned
# 18378  32730  Infantry fighting vehicles  BMP-1AM 675-sb3KDZ  Destroyed
# 18379  32731  Infantry fighting vehicles               BMP-3  Destroyed
# 18380  32732  Infantry fighting vehicles            BMP-2(K)  Destroyed
# 18381  32733                       Tanks        Unknown tank  Destroyed
#
#       lost_by        date                                   nearest_location  \
# 0      Russia  2022-03-14                    Rubizhne, Sievierodonetsk raion
# 1      Russia  2022-03-16                           Mariupol, Mariupol raion
# 2      Russia  2022-03-16                           Mariupol, Mariupol raion
# 3      Russia  2022-03-17                           Mariupol, Mariupol raion
# 4      Russia  2022-03-31                    Rubizhne, Sievierodonetsk raion
# ...       ...         ...                                                ...
# 18377  Russia  2024-12-21                               Darino, Sudzha raion
# 18378  Russia  2024-12-21                         Sukhi Yaly, Pokrovsk raion
# 18379  Russia  2024-11-30       Pershotravneve (Borova hromada), Izium raion
# 18380  Russia  2024-12-19  Pishchane (Petropavlivka hromada), Kupiansk raion
# 18381  Russia  2024-12-19  Pishchane (Petropavlivka hromada), Kupiansk raion
#
#                                          geo  unit  \
# 0                        49.027241,38.343374  None
# 1       47.099125851628806,37.52371337039075  None
# 2        47.09869256359657,37.52353235165147  None
# 3      47.098139835697424,37.640174323260645  None
# 4                          49.01122,38.39844  None
# ...                                      ...   ...
# 18377                    51.267278,35.031333  None
# 18378                                   None  None
# 18379                                   None  None
# 18380                    49.572472,37.764583  None
# 18381                     49.572333,37.76475  None
#
#                                   tags
# 0                                 None
# 1      Turretless, Z, Mine plow/roller
# 2                            Shattered
# 3                        Turretless, Z
# 4                                    Z
# ...                                ...
# 18377                        Cope cage
# 18378                        Cope cage
# 18379                Cope cage, Jammer
# 18380            Turretless, Cope cage
# 18381     Cope cage, Additional armour
#
# [18382 rows x 10 columns]

# %%
# Save the DataFrame to a CSV file
df.to_csv(csv_file, index=False, encoding='utf-8')
print(f"Data saved to {csv_file}")
# Out:
# Data saved to russia_losses.csv
